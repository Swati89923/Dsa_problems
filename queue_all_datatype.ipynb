# %%
class Queue:

    def __init__(self):
        self.queue=[]

    def enqueue(self,data):
        self.queue.append(data)
    
    def dequeue(self):
        self.queue.pop(0)
    
    def get_front(self):
        return self.queue[0]
    
    def get_rear(self):
        return self.queue[-1]
    def display(self):
        return self.queue

q1=Queue()
q1.enqueue(9)
q1.display()
# Out:
# [9]

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class Queue:

    def __init__(self):
        self.front = None
        self.rear = None

    def enqueue(self, data):
        n = Node(data)
        if self.front is None:
            self.front = n
            self.rear = n
        else:
            self.rear.next = n
            self.rear = n

    def dequeue(self):
        if self.front is None:
            return "Not possible"
        self.front =self.front.next

    def get_size(self):
        temp = self.front
        count = 0
        while temp is not None:
            count += 1
            temp = temp.next
        return count

    def get_front(self):
        return self.front

    def get_rear(self):
        return self.rear

    def display(self):
        temp = self.front
        while temp is not None:
            print(temp.data, end=" ")
            temp = temp.next
        print()

q1 = Queue()
q1.enqueue(91)
q1.enqueue(97)
q1.enqueue(99)
q1.enqueue(97)
q1.enqueue(94)
q1.enqueue(90)
q1.display()
q1.dequeue()
q1.display()
# Out:
# 91 97 99 97 94 90
# 97 99 97 94 90

# %%
class Queue:
    def __init__(self, capacity):
        self.front = -1
        self.rear = -1
        self.capacity = capacity
        self.items = [None] * self.capacity

    def is_full(self):
        return self.rear == self.capacity - 1

    def is_empty(self):
        return self.front == -1 or self.front > self.rear

    def enqueue(self, data):
        if self.is_full():
            print("Queue is full. Enqueue not possible.")
            return
        if self.front == -1:
            self.front = 0
        self.rear += 1
        self.items[self.rear] = data

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty. Dequeue not possible.")
            return
        data = self.items[self.front]
        self.front += 1
        return data

    def display(self):  # ✅ Added minimal method to fix
        if self.is_empty():
            print("Queue is empty.")
            return
        for i in range(self.front, self.rear + 1):
            print(self.items[i], end=" ")
        print()

# Test
q1 = Queue(4)
q1.enqueue(1)
q1.enqueue(2)
q1.enqueue(3)
q1.enqueue(45)
q1.enqueue(67)  # This won't be added (Queue is full)
q1.display()

q1.dequeue()
q1.dequeue()
q1.dequeue()
q1.dequeue()
q1.dequeue()  # One extra dequeue (Queue is empty)
q1.display()
# Out:
# Queue is full. Enqueue not possible.
# 1 2 3 45
# Queue is empty. Dequeue not possible.
# Queue is empty.

# %% [markdown]
# Doubly queue using linkedlist

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class Dqueue:
    def __init__(self):
        self.front = None
        self.rear = None

    def enqueue_first(self, item):
        n = Node(item)
        if self.front == None:
            self.front = self.rear = n
        else:
            n.next = self.front
            self.front = n 

    def enqueue_last(self, item):
        n = Node(item)
        if self.front == None:
            self.front = self.rear = n  
        else:
            self.rear.next = n
            self.rear = n

    def dequeue_first(self):
        if self.front == None:
            print("Queue is empty")
            return
        self.front = self.front.next
        if self.front == None:
            self.rear = None

    def dequeue_last(self):
     if self.front == None:
        print("Queue is empty")
        return
     if self.front == self.rear:
        self.front = self.rear = None
     else:
        temp = self.front
        while temp.next != self.rear:
            temp = temp.next
        temp.next = None
        self.rear = temp  


    def display(self):
        temp = self.front
        while temp != None:
            print(temp.data, end=" ")
            temp = temp.next
        print()
dq2 = Dqueue()
dq2.enqueue_first(91)
dq2.enqueue_first(92)
dq2.enqueue_first(93)
dq2.enqueue_first(99)
dq2.display()
dq2.dequeue_last()
dq2.display()
# Out:
# 99 93 92 91
# 99 93 92

# %% [markdown]
# Dqueue using array

# %%
class DQueue:
    def __init__(self, capacity):
        self.capacity = capacity
        self.items = [None] * capacity
        self.front = -1
        self.rear = -1

    def is_full(self):
        return (self.rear + 1) % self.capacity == self.front

    def is_empty(self):
        return self.front == -1

    def enqueue_first(self, item):
        if self.is_full():
            print("Queue is full, cannot insert at front")
            return
        if self.is_empty():
            self.front = self.rear = 0
        else:
            self.front = (self.front - 1 + self.capacity) % self.capacity
        self.items[self.front] = item

    def enqueue_last(self, item):
        if self.is_full():
            print("Queue is full, cannot insert at rear")
            return
        if self.is_empty():
            self.front = self.rear = 0
        else:
            self.rear = (self.rear + 1) % self.capacity
        self.items[self.rear] = item

    def dequeue_first(self):
        if self.is_empty():
            print("Queue is empty, cannot delete from front")
            return
        removed = self.items[self.front]
        if self.front == self.rear:  # only one element
            self.front = self.rear = -1
        else:
            self.front = (self.front + 1) % self.capacity
        return removed

    def dequeue_last(self):
        if self.is_empty():
            print("Queue is empty, cannot delete from rear")
            return
        removed = self.items[self.rear]
        if self.front == self.rear:  # only one element
            self.front = self.rear = -1
        else:
            self.rear = (self.rear - 1 + self.capacity) % self.capacity
        return removed

    def display(self):
        if self.is_empty():
            print("Queue is empty")
            return
        i = self.front
        print("Queue contents:", end=" ")
        while True:
            print(self.items[i], end=" ")
            if i == self.rear:
                break
            i = (i + 1) % self.capacity
        print()
q1=DQueue(8)
q1.enqueue_first(3)
q1.enqueue_first(7)
q1.enqueue_first(9)
q1.enqueue_first(11)
q1.enqueue_first(15)
q1.display()
# Out:
# Queue contents: 15 11 9 7 3

# %%
# class Cqueue:

#     def  __init__(self,capacity):
#         self.front=-1
#         self.rear=-1
#         self.capacity=capacity
#         self.items=[None]*self.capacity
#     def is_empty(self):
#         return self.front==-1 or self.front>self.rear
#     def is_full(self):
#         return self.rear==self.capacity-1
#     def insert_element(self,data):
#         if self.is_full():
#             self.front=0
#             self.rear=0
#             self.front=self.rear=data
#         self.items[self.rear]=data
#         self.rear=(self.rear+1)%self.capacity
#         self.rear+=1
#     def delete_element(self):
#         if self.is_empty():
#             print("Oops can't do deletion ! queue is empty")
#             return
#         data=self.items[self.front]
#         self.front=(self.front+1)%self.capacity
#         self.front+=1
#     def get_front(self):
#         return self.front
#     def get_rear(self):
#         return self.rear
#     def display(self):
#         for  i in self.items:
#             print(self.items[i] ,end=" ")
#         print()


class Cqueue:
    def __init__(self, capacity):
        self.front = -1
        self.rear = -1
        self.capacity = capacity
        self.items = [None] * capacity

    def is_empty(self):
        return self.front == -1

    def is_full(self):
        return (self.rear + 1) % self.capacity == self.front

    def insert_element(self, data):
        if self.is_full():
            print("Queue is full. Cannot insert.")
            return
        if self.is_empty():
            self.front = 0
        self.rear = (self.rear + 1) % self.capacity
        self.items[self.rear] = data

    def delete_element(self):
        if self.is_empty():
            print("Oops can't do deletion! Queue is empty.")
            return
        removed = self.items[self.front]
        if self.front == self.rear:  # Only one element
            self.front = self.rear = -1
        else:
            self.front = (self.front + 1) % self.capacity
        return removed

    def get_front(self):
        if self.is_empty():
            return None
        return self.items[self.front]

    def get_rear(self):
        if self.is_empty():
            return None
        return self.items[self.rear]

    def display(self):
        if self.is_empty():
            print("Queue is empty")
            return
        i = self.front
        while True:
            print(self.items[i], end=" ")
            if i == self.rear:
                break
            i = (i + 1) % self.capacity
        print()
q = Cqueue(5)
q.insert_element(10)
q.insert_element(20)
q.insert_element(30)
q.display()  # Output: 10 20 30
q.delete_element()
q.display()  # Output: 20 30
# Out:
# 10 20 30
# 20 30

# %% [markdown]
# Cll

# %%
class CircularQueue:
    def __init__(self, capacity):
        self.queue = [None] * capacity  
        self.front = -1  
        self.rear = -1  
        self.capacity = capacity  
        self.size = 0  

    def enqueue(self, item):
        if self.isFull():
            print("Queue is full! Cannot insert", item)
            return
        if self.size ==0:
            self.front = 0
            self.rear = (self.rear + 1) % self.capacity
        else:
            self.rear = (self.rear + 1) % self.capacity
        self.queue[self.rear] = item
        self.size += 1

    def dequeue(self):
        if self.isEmpty():
            print("Queue is empty! Cannot dequeue.")
            return None
        item = self.queue[self.front]
        self.queue[self.front] = None  
        if self.front == self.rear:
            self.front = -1
            self.rear = -1
        else:
            self.front = (self.front + 1) % self.capacity
        self.size -= 1
        return item

    def isFull(self):
        return self.size == self.capacity

    def isEmpty(self):
        return self.size == 0

    def display(self):
        if self.isEmpty():
            print("Queue is empty!")
            return
        # print(self.queue)
        print("Circular Queue:", end=" ")
        index = self.front
        for _ in range(self.size):
            print(self.queue[index], end=" | ")
            index = (index + 1) % self.capacity
        print()

cq = CircularQueue(5)
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(40)
cq.enqueue(50)
cq.enqueue(60)  
cq.display()  
cq.dequeue()
cq.dequeue()
cq.display()  
cq.enqueue(60)
cq.enqueue(70)  
cq.display()
# Out:
# Queue is full! Cannot insert 60
# Circular Queue: 10 | 20 | 30 | 40 | 50 |
# Circular Queue: 30 | 40 | 50 |
# Circular Queue: 30 | 40 | 50 | 60 | 70 |

# %%
# circular queue using linkedlist
class Node:

    def __init__(self,data=None,next=None):
        self.data=data
        self.next=next

class CircularQueue:

    def __init__(self):
        self.start=None
    def enqueue(self,data):
       n=Node(data)
       if self.start is None:
           self.start=n
           n.next=self.start
       else:
         temp=self.start
         while temp.next is not self.start:
           temp=temp.next
         temp.next=n
         n.next=self.start
    def dequeue(self):
       if self.start is None:
          print("queue is empty")
          return
       if self.start==self.start.next:
          self.start=None
       else:
          temp=self.start
          while temp.next is not self.start:
             temp=temp.next
          temp.next=self.start.next
          self.start=self.start.next
    def display(self):
       if self.start is None:
          return None
       temp=self.start
       while True:
          print(temp.data,end=" ")
          temp=temp.next
          if temp ==self.start:
             break
       print()   
cq = CircularQueue()
cq.enqueue(10)
cq.enqueue(20)
cq.enqueue(30)
cq.enqueue(40)
cq.display()

cq.dequeue()
cq.display()

cq.dequeue()
cq.display()

cq.dequeue()
cq.display()
# Out:
# 10 20 30 40
# 20 30 40
# 30 40
# 40

# %% [markdown]
# Priority Queue

# %%
class Priority_Queue:

    def __init__(self):
        self.items=[]

    def is_empty(self):
        return len(self.items)==0

    
    def push(self,data,priority):
        index=0
        while index<len(self.items) and self.items[index][1]<=priority:
            index+=1
        self.items.insert(index,(data,priority))

    def pop(self):
        if self.is_empty():
            raise IndexError("Priority queue is Empty")
        return self.items.pop(0)[0]
    def size(self):
        return len(self.items)
    def display(self):
        return self.items
p=Priority_Queue()
p.push("swati",1)
p.push("swati2",2)
p.push("swati4",9)
p.push("swati2",7)
p.display()
p.pop()
# Out:
# 'swati'

# %%
class Node:
    def __init__(self,item=None,priority=None,next=None):
        self.item=item
        self.priority=priority
        self.next=next
    
class Priority_queue:
    def __init__(self):
        self.start=None
        self.item_count=0
    def push(self,data,priority):
        n=Node(data,priority)
        if not self.start or priority < self.start.priority:
            n.next=self.start
            self.start=n
        else:
            temp=self.start
            while temp.next and temp.next.priority<=priority:
                temp=temp.next
            n.next=temp.next
            temp.next=n
        self.item_count+=1
    def is_empty(self):
        return self.start==None
    
    def pop(self):
        if self.is_empty():
            raise IndexError("pq is empty")
        data=self.start.item
        self.start=self.start.next
        self.item_count-=1
        return data
    def size(self):
        return self.item_count
    def display(self):
        temp=self.start
        while temp is not None:
            print((temp.item,temp.priority), end=" ")
            temp=temp.next
        print()
p=Priority_queue()
p.push("swati",1)
p.push("swati2",2)
p.push("swati4",9)
p.push("swati2",7)
p.display()
p.pop()
# Out:
# ('swati', 1) ('swati2', 2) ('swati2', 7) ('swati4', 9)
# 'swati'

# %%
class Node:
    def __init__(self, data=None, priority=None, next=None):
        self.data = data
        self.priority = priority
        self.next = next

class PriorityQueue:
    def __init__(self):
        self.start = None
        self.item_count = 0

    def enqueue(self, data, priority):
        new_node = Node(data, priority)
        
        # Inserting at front if queue is empty or new node has higher priority (lower value)
        if not self.start or self.start.priority > priority:
            new_node.next = self.start
            self.start = new_node
        else:
            # Traverse to find the correct position based on priority
            temp = self.start
            while temp.next and temp.next.priority <= priority:
                temp = temp.next
            
            # Insert node in its correct position
            new_node.next = temp.next
            temp.next = new_node

        self.item_count += 1

    def dequeue(self):
        if self.start is None:
            print("Priority queue is empty.")
            return None
        item = self.start.data
        self.start = self.start.next
        self.item_count -= 1
        return item

    def display(self):
        if self.start is None:
            print("Priority queue is empty.")
            return
        temp = self.start
        while temp:
            print((temp.data, temp.priority), end=" ")
            temp = temp.next
        print()

# Driver code
p1 = PriorityQueue()
p1.enqueue(9, 0)
p1.enqueue(5, 2)
p1.enqueue(7, 1)
p1.enqueue(3, 0)
p1.display()  # Expected order: (9,0) (3,0) (7,1) (5,2)
# Out:
# (9, 0) (3, 0) (7, 1) (5, 2)

# %%
class Node:
    def __init__(self,item=None,priority=None,next=None):
        self.item=item
        self.priority=priority
        self.next=next
class Priority_queue:
    def __init__(self):
        self.start=[]
        
    def is_empty(self):
        return self.start == None
    def push(self,data,priority):
        n=Node(data,priority)
        if self.start is None:
            n.next=self.start
            self.start=n
        temp=self.start
        while temp.next and temp.next.priority<=priority:
            temp=temp.next
        n.next=temp.next
        temp.next=n
    def pop(self):
        if  self.start is None:
            return None
        data=self.start.item
        self.start=self.start.next
        return data
    def display(self):
        temp=self.start
        while temp is not None:
            temp=temp.next
            print((temp.data,temp.priority),end=" ")
        print()
p1=Priority_Queue()
p1.push("ram",0)
p1.push("shayam",1)
p1.push("dhanu",9)
p1.push("daksh",3)
p1.display()
#p1.pop()
# Out:
# [('ram', 0), ('shayam', 1), ('daksh', 3), ('dhanu', 9)]

# %%
# Queue implementation using 2 stacks (lists) - Pure Python

class QueueUsingStack:
    def __init__(self):
        # s1: input stack (naye elements yahan push honge)
        # s2: output stack (queue ke front se element pop karne ke liye)
        self.s1 = []
        self.s2 = []

    def enqueue(self, x):
        # Element ko input stack (s1) mein daalo
        self.s1.append(x)

    def dequeue(self):
        # Agar s2 khali hai to s1 ke elements ko reverse karke s2 mein daalo
        if self.is_empty():
            print("Queue khali hai!")
            return None

        if not self.s2:
            while self.s1:
                self.s2.append(self.s1.pop())  # s1 ke elements ko ulta kar ke s2 mein daal rahe hain

        # s2 ka top element (jo sabse purana hai) return karo
        return self.s2.pop()

    def front(self):
        # Queue ka front element dikhata hai bina hataaye
        if self.is_empty():
            print("Queue khali hai!")
            return None

        if not self.s2:
            while self.s1:
                self.s2.append(self.s1.pop())

        return self.s2[-1]

    def is_empty(self):
        # Agar dono stacks khali hain to queue bhi khali hai
        return len(self.s1) == 0 and len(self.s2) == 0
    def display(self):
      if self.is_empty():
        print("Queue khali hai!")
        return

      print("Queue (front to rear):", end=" ")

      # Print elements of s2 from top to bottom (reversed)
      for i in range(len(self.s2) - 1, -1, -1):
        print(self.s2[i], end=" ")

       # Print elements of s1 from bottom to top
      for i in range(len(self.s1)):
        print(self.s1[i], end=" ")

      print()


# ---------- Example Usage ----------
q = QueueUsingStack()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

print("Front element hai:", q.front())   # Output: 10
print("Dequeue kiya:", q.dequeue())      # Output: 10
print("Ab front element hai:", q.front())  # Output: 20
# Out:
# Front element hai: 10
# Dequeue kiya: 10
# Ab front element hai: 20

# %%
class queueusingstack:

    def __init__(self):
        self.s1=[]
        self.s2=[]
    def enqueue(self,x):
        self.s2.append(x)
    def dequeue(self):
        if self.is_empty():
            print("queue iss emppty")
            return
        if not self.s2:
            while self.s1:
                self.s2.append(self.s1.pop())
        return self.s2.pop()
    def get_front(self):
        if self.is_empty():
            print("queue is empty")
            return 
        if not self.s2:
            while self.s1:
                self.s2.append(self.s1.pop())
        return self.s2[0]
    def is_empty(self):
        return len(self.s1)==0 and len(self.s2)==0
    def size(self):
        return len(self.s1)+len(self.s2)
    def display(self):
        if self.is_empty():
            print("queue is empty")
            return
        for i in range(len(self.s2)-1,-1,-1):
            print(self.s2[i],end=" ")
        for j in range(len(self.s1)):
            print(self.s1[j],end=" ")
q1=queueusingstack()
q1.enqueue(11)
q1.enqueue(13)
q1.enqueue(10)
q1.enqueue(15)
q1.display()
q1.dequeue()
# Out:
# 15 10 13 11
# 15

# %%
# Node class for Doubly Linked List
class Node:
    def __init__(self, data):
        self.data = data      # Data store karega
        self.prev = None      # Previous node ka reference
        self.next = None      # Next node ka reference

# Queue class using Doubly Linked List
class Queue:
    def __init__(self):
        self.front = None     # Queue ka front (dequeue yahin se hoga)
        self.rear = None      # Queue ka rear (enqueue yahan hoga)

    def enqueue(self, value):
        # Naya node banate hain
        new_node = Node(value)

        if self.rear is None:
            # Agar queue empty hai to front aur rear dono new_node honge
            self.front = self.rear = new_node
        else:
            # Rear ke next ko new node se link karo
            self.rear.next = new_node
            new_node.prev = self.rear
            self.rear = new_node  # Rear ko update karo

    def dequeue(self):
        if self.front is None:
            print("Queue khali hai!")
            return None

        # Front node ko hata rahe hain
        value = self.front.data
        self.front = self.front.next

        if self.front is not None:
            self.front.prev = None
        else:
            # Agar ek hi element tha, to rear bhi None kar do
            self.rear = None

        return value

    def peek(self):
        # Front element ko dikhata hai bina hataaye
        if self.front is None:
            print("Queue khali hai!")
            return None
        return self.front.data

    def is_empty(self):
        return self.front is None


# ---------- Example Usage ----------
q = Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

print("Front element hai:", q.peek())      # Output: 10
print("Dequeue kiya:", q.dequeue())        # Output: 10
print("Ab front element hai:", q.peek())   # Output: 20
# Out:
# Front element hai: 10
# Dequeue kiya: 10
# Ab front element hai: 20
